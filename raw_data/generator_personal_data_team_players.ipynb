# %%
import pandas as pd
import json

# %%
## Función para generar datos personales de los jugadores del equipo
def generatePersonalData():
    
    playersTeam = []
    
    player = {}
    player['id'] = 'TC01'
    player['Name'] = 'Thibaut'
    player['Surname'] = 'Courtois'
    player['Position'] = 'Portero'
    player['Weight'] = '96'
    player['Height'] = '199'
    player['Birthdate'] = '1992/05/11'
    player['Birthplace'] = 'Bélgica'
    player['Number'] = '1'
    playersTeam.append(player)
    
    player = {}
    player['id'] = 'DC02'
    player['Name'] = ' Daniel'
    player['Surname'] = 'Carvajal'
    player['Position'] = 'Defensa'
    player['Weight'] = '73'
    player['Height'] = '173'
    player['Birthdate'] = '1992/01/11'
    player['Birthplace'] = 'España'
    player['Number'] = '2'
    playersTeam.append(player)
    
    player = {}
    player['id'] = 'EM03'
    player['Name'] = 'Eder'
    player['Surname'] = 'Militao'
    player['Position'] = 'Defensa'
    player['Weight'] = '79'
    player['Height'] = '186'
    player['Birthdate'] = '1998/01/18'
    player['Birthplace'] = 'Brasil'
    player['Number'] = '3'
    playersTeam.append(player)
    
    player = {}
    player['id'] = 'SR04'
    player['Name'] = 'Sergio'
    player['Surname'] = 'Ramos'
    player['Position'] = 'Defensa'
    player['Weight'] = '82'
    player['Height'] = '184'
    player['Birthdate'] = '1986/03/30'
    player['Birthplace'] = 'España'
    player['Number'] = '4'
    playersTeam.append(player)
    
    player = {}
    player['id'] = 'RV05'
    player['Name'] = 'Raphael'
    player['Surname'] = 'Varane'
    player['Position'] = 'Defensa'
    player['Weight'] = '81'
    player['Height'] = '191'
    player['Birthdate'] = '1993/04/25'
    player['Birthplace'] = 'Francia'
    player['Number'] = '5'
    playersTeam.append(player)
    
    player = {}
    player['id'] = 'TK08'
    player['Name'] = 'Toni'
    player['Surname'] = 'Kroos'
    player['Position'] = 'Centrocampista'
    player['Weight'] = '76'
    player['Height'] = '183'
    player['Birthdate'] = '1990/01/04'
    player['Birthplace'] = 'Alemania'
    player['Number'] = '8'
    playersTeam.append(player)
    
    player = {}
    player['id'] = 'LM10'
    player['Name'] = 'Luka'
    player['Surname'] = 'Modric'
    player['Position'] = 'Centrocampista'
    player['Weight'] = '66'
    player['Height'] = '172'
    player['Birthdate'] = '1985/09/09'
    player['Birthplace'] = 'Croacia'
    player['Number'] = '10'
    playersTeam.append(player)
    
    player = {}
    player['id'] = 'CC14'
    player['Name'] = 'Carlos Enrique'
    player['Surname'] = 'Casemiro'
    player['Position'] = 'Centrocampista'
    player['Weight'] = '84'
    player['Height'] = '185'
    player['Birthdate'] = '1992/02/23'
    player['Birthplace'] = 'Brasil'
    player['Number'] = '14'
    playersTeam.append(player)
    
    player = {}
    player['id'] = 'KB09'
    player['Name'] = 'Karim'
    player['Surname'] = 'Benzema'
    player['Position'] = 'Delantero'
    player['Weight'] = '81'
    player['Height'] = '185'
    player['Birthdate'] = '1987/12/19'
    player['Birthplace'] = 'Francia'
    player['Number'] = '9'
    playersTeam.append(player)
    
    player = {}
    player['id'] = 'EH07'
    player['Name'] = 'Eden'
    player['Surname'] = 'Hazard'
    player['Position'] = 'Delantero'
    player['Weight'] = '74'
    player['Height'] = '175'
    player['Birthdate'] = '1991/01/07'
    player['Birthplace'] = 'Bélgica'
    player['Number'] = '7'
    playersTeam.append(player)
    
    player = {}
    player['id'] = 'VJ20'
    player['Name'] = 'Vinicius'
    player['Surname'] = 'Junior'
    player['Position'] = 'Delantero'
    player['Weight'] = '73'
    player['Height'] = '176'
    player['Birthdate'] = '2000/07/12'
    player['Birthplace'] = 'Brasil'
    player['Number'] = '20'
    playersTeam.append(player)
    
    return playersTeam

# %%
## Generamos información personal de los jugadores del equipo y la persistimos en fichero
personalInformationPlayersTeam = pd.DataFrame(generatePersonalData())
personalInformationPlayersTeam.to_json(r'dataPlayersTeam.json',orient='records')
print('Done!')
